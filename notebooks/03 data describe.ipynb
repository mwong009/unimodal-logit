# %%
import pandas as pd

df = pd.read_csv("../dataset/tempe_cleaneddata.csv", sep="\t")
df.head(5)
# Out:
#    incidentid  severity  age  total_injuries  alcohol  hour_morning  \
# 0     2584487         0    0               0        0             0
# 1     2584442         2   26               3        0             1
# 2     2589844         0   19               0        0             1
# 3     2579417         0   43               0        0             1
# 4     2584480         0   34               0        0             1
#
#    hour_afternoon  hour_night  hour_latenight  nonintersection  ...  \
# 0               0           1               0                1  ...
# 1               0           0               0                0  ...
# 2               0           0               0                1  ...
# 3               0           0               0                0  ...
# 4               0           0               0                1  ...
#
#    cause_yield  cause_unsafe  cause_signal  cause_following  \
# 0            0             1             0                0
# ...

# %%
out = df.describe()
pd.options.display.max_rows = len(df.columns)
out.loc[["mean", "std"]].transpose().round(3)
# Out:
#                              mean         std
# incidentid            3120450.673  321513.903
# severity                    0.456       0.764
# age                        30.234      18.150
# total_injuries              0.441       0.795
# alcohol                     0.044       0.205
# hour_morning                0.257       0.437
# hour_afternoon              0.471       0.499
# hour_night                  0.215       0.411
# hour_latenight              0.057       0.231
# nonintersection             0.429       0.495
# light_daylight              0.719       0.449
# light_darklighted           0.222       0.415
# light_darknotlighted        0.007       0.081
# light_dawndusk              0.041       0.198
# meteo_cloudy                0.054       0.225
# meteo_rain                  0.023       0.151
# surf_wet                    0.032       0.175
# type_cyclist                0.022       0.148
# type_pedestrian             0.007       0.085
# ...
